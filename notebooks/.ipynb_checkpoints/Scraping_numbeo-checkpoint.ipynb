# %% [markdown]
# # Obtaining socio-economic data
# #### Using pandas read_html to collect table data from https://www.numbeo.com/quality-of-life/in/Berlin

# %%
import pandas as pd
import lxml

# %% [markdown]
# ## 1. Getting city data
# ### 1.1 Define city list

# %%
city_list = ['Amsterdam', 'Andorra-La-Vella', 'Athens', 'Belgrade', 'Berlin', 'Bern', 
             'Bratislava', 'Brussels', 'Bucharest', 'Budapest', 'Chisinau', 'Copenhagen', 
             'Dublin', 'Helsinki', 'Kiev', 'Lisbon', 'Ljubljana', 'London', 'Luxembourg', 
             'Madrid', 'Minsk', 'Monaco', 'Moscow', 'Nicosia', 'Nuuk', 'Oslo', 'Paris', 
             'Podgorica', 'Prague', 'Reykjavik', 'Riga', 'Rome', 'San-Marino', 'Sarajevo', 
             'Skopje', 'Sofia', 'Stockholm', 'Tallinn', 'Tirana', 'Vaduz', 'Valletta', 'Vatican-City', 
             'Vienna', 'Vilnius', 'Warsaw', 'Zagreb']

# %% [markdown]
# ### 1.2 Creating a function to obtain data and put it into a dataframe for processing and modelling

# %%
test_list = ["Vienna", "Berlin"]

# %%
def get_city_info(city_list) -> list:
    
    # create empty database
    df = pd.DataFrame()
    errors = []
    
    # iterate over list of cities to obtain table data from Numbeo
    for city in city_list:
        try:
            table = pd.read_html(f"https://www.numbeo.com/quality-of-life/in/{city}")[3]
            table = (table.assign(city=city)
                      .rename(columns={0:"category", 1:"numeral", 2:"level"})
                      .drop([table.index[8]]))
            df = df.append(table)
        
        except:
            errors.append(city)
    
    df.reset_index(inplace=True, drop=True)
    
    # df = df.pivot(index="city", columns="category", values=["numeral", "level"])
    
    # colnames = ['climate', 'cost_of_living', 'health_care', 'pollution', 'property_income_ratio', 'purchasing_power',
                #'safety', 'traffic_time', 'quality_of_life', 'climate_level', 'cost_of_living_level',
                #'health_care_level', 'pollution_level', 'property_income_ratio_level', 'purchasing_power_level',
                #'safety_level', 'traffic_time_level', 'quality_of_life_level']
    #df.columns = colnames
    #df = df.reset_index()
        
    return df, errors

# %%
get_city_info(test_list)
# Out:
# (                          category  numeral      level    city
#  0           Purchasing Power Index    83.38   Moderate  Vienna
#  1                     Safety Index    75.85       High  Vienna
#  2                Health Care Index    78.83       High  Vienna
#  3                    Climate Index    81.77  Very High  Vienna
#  4             Cost of Living Index    68.69   Moderate  Vienna
#  5   Property Price to Income Ratio    13.72       High  Vienna
#  6       Traffic Commute Time Index    26.78        Low  Vienna
#  7                  Pollution Index    18.15   Very Low  Vienna
#  8         ƒ Quality of Life Index:   183.99  Very High  Vienna
#  9           Purchasing Power Index    97.17       High  Berlin
#  10                    Safety Index    58.92   Moderate  Berlin
#  11               Health Care Index    69.68       High  Berlin
#  12                   Climate Index    83.35  Very High  Berlin
#  13            Cost of Living Index    67.91   Moderate  Berlin
#  14  Property Price to Income Ratio     9.59   Moderate  Berlin
#  15      Traffic Commute Time Index    34.18        Low  Berlin
#  16                 Pollution Index    39.45        Low  Berlin
#  17        ƒ Quality of Life Index:   164.21  Very High  Berlin,
#  [])

# %% [markdown]
# ## 2. Final data-set
# ### 2.1 Checking for cities not covered by Numbeo

# %%
# get_city_info(city_list)

# %%
drop_cities = ['San-Marino', 'Vaduz', 'Vatican-City']

update_cities = [city for city in city_list if city not in drop_cities]

# %%
print(update_cities)
# Out:
# ['Amsterdam', 'Andorra-La-Vella', 'Athens', 'Belgrade', 'Berlin', 'Bern', 'Bratislava', 'Brussels', 'Bucharest', 'Budapest', 'Chisinau', 'Copenhagen', 'Dublin', 'Helsinki', 'Kiev', 'Lisbon', 'Ljubljana', 'London', 'Luxembourg', 'Madrid', 'Minsk', 'Monaco', 'Moscow', 'Nicosia', 'Nuuk', 'Oslo', 'Paris', 'Podgorica', 'Prague', 'Reykjavik', 'Riga', 'Rome', 'Sarajevo', 'Skopje', 'Sofia', 'Stockholm', 'Tallinn', 'Tirana', 'Valletta', 'Vienna', 'Vilnius', 'Warsaw', 'Zagreb']

# %% [markdown]
# ### 2.2 Now rerunning function with updated list

# %%
# get_city_info(update_cities)

# %% [markdown]
# ### 2.3 There seem to be no errors coming up, now to rewrite the function, so it returns a data-set again

# %%
def get_city(city_list) -> list:
    
    # create empty database
    df = pd.DataFrame()
    
    # iterate over list of cities to obtain table data from Numbeo    
    # removing index position 8, because it refers to a border
    for city in city_list:
        table = pd.read_html(f"https://www.numbeo.com/quality-of-life/in/{city}")[3]
        table = (table.assign(city=city)
                      .rename(columns={0:"category", 1:"numeral", 2:"level"})
                )
        df = df.append(table)
    
    df.reset_index(inplace=True, drop=True)
  
    return df

# %%
#all_cities = 
get_city(test_list)
# Out:
#                           category  numeral      level    city
# 0           Purchasing Power Index    83.38   Moderate  Vienna
# 1                     Safety Index    75.85       High  Vienna
# 2                Health Care Index    78.83       High  Vienna
# 3                    Climate Index    81.77  Very High  Vienna
# 4             Cost of Living Index    68.69   Moderate  Vienna
# 5   Property Price to Income Ratio    13.72       High  Vienna
# 6       Traffic Commute Time Index    26.78        Low  Vienna
# 7                  Pollution Index    18.15   Very Low  Vienna
# 8                              NaN      NaN        NaN  Vienna
# 9         ƒ Quality of Life Index:   183.99  Very High  Vienna
# 10          Purchasing Power Index    97.17       High  Berlin
# 11                    Safety Index    58.92   Moderate  Berlin
# 12               Health Care Index    69.68       High  Berlin
# 13                   Climate Index    83.35  Very High  Berlin
# 14            Cost of Living Index    67.91   Moderate  Berlin
# 15  Property Price to Income Ratio     9.59   Moderate  Berlin
# 16      Traffic Commute Time Index    34.18        Low  Berlin
# 17                 Pollution Index    39.45        Low  Berlin
# 18                             NaN      NaN        NaN  Berlin
# 19        ƒ Quality of Life Index:   164.21  Very High  Berlin

# %%
# all_cities

# %% [markdown]
# ### 2.4 Checking values of Index and Unnamed: 1 columns
# There seems to be a city whose data was pushed back by one.

# %%
# all_cities["Index"].value_counts()

# %%
# all_cities["Unnamed: 1"].value_counts()

# %%
# all_cities.loc[all_cities["Unnamed: 1"] == 209.07]

# %% [markdown]
# The data for the city of Bern seems to have been scraped incorrectly. Let's check what data Numbeo actually has available.

# %%
# pd.read_html(f"https://www.numbeo.com/quality-of-life/in/Bern")[3]

# %% [markdown]
# Perhaps we are reading the wrong table from Numbeo, let's try the others.

# %%
# pd.read_html(f"https://www.numbeo.com/quality-of-life/in/Bern")[4]

# %% [markdown]
# It seems as though there is not enough user information for Bern and there is a notice table in the html
# pushing it to index position 4. I think we'll delete Bern, as it does not have enough data.

# %%
update_cities.remove("Bern")

# %%
print(update_cities)
# Out:
# ['Amsterdam', 'Andorra-La-Vella', 'Athens', 'Belgrade', 'Berlin', 'Bratislava', 'Brussels', 'Bucharest', 'Budapest', 'Chisinau', 'Copenhagen', 'Dublin', 'Helsinki', 'Kiev', 'Lisbon', 'Ljubljana', 'London', 'Luxembourg', 'Madrid', 'Minsk', 'Monaco', 'Moscow', 'Nicosia', 'Nuuk', 'Oslo', 'Paris', 'Podgorica', 'Prague', 'Reykjavik', 'Riga', 'Rome', 'Sarajevo', 'Skopje', 'Sofia', 'Stockholm', 'Tallinn', 'Tirana', 'Valletta', 'Vienna', 'Vilnius', 'Warsaw', 'Zagreb']

# %%
# final_cities = get_city(update_cities)

# %%
def get_city(city_list) -> list:
    
    # create empty database
    df = pd.DataFrame()
    
    # iterate over list of cities to obtain table data from Numbeo    
    # removing index position 8, because it refers to a border
    for city in city_list:
        table = pd.read_html(f"https://www.numbeo.com/quality-of-life/in/{city}")[3]
        table = (table.assign(city=city)
                      .rename(columns={0:"category", 1:"numeral", 2:"level"})
                      .drop([table.index[8]])
                )
        df = df.append(table)
    
    df.reset_index(inplace=True, drop=True)
  
    return df

# %%
final_cities = get_city(update_cities)

# %%
final_cities.head(20)
# Out:
#                           category numeral      level              city
# 0           Purchasing Power Index    80.9   Moderate         Amsterdam
# 1                     Safety Index   67.32       High         Amsterdam
# 2                Health Care Index   69.45       High         Amsterdam
# 3                    Climate Index   87.45  Very High         Amsterdam
# 4             Cost of Living Index   84.26   Moderate         Amsterdam
# 5   Property Price to Income Ratio   10.98   Moderate         Amsterdam
# 6       Traffic Commute Time Index   29.88        Low         Amsterdam
# 7                  Pollution Index   30.79        Low         Amsterdam
# 8         ƒ Quality of Life Index:  168.08  Very High         Amsterdam
# 9           Purchasing Power Index   81.72   Moderate  Andorra-La-Vella
# 10                    Safety Index   87.16  Very High  Andorra-La-Vella
# 11               Health Care Index   69.44       High  Andorra-La-Vella
# 12                   Climate Index       ?        NaN  Andorra-La-Vella
# 13            Cost of Living Index   66.75   Moderate  Andorra-La-Vella
# 14  Property Price to Income Ratio    7.44        Low  Andorra-La-Vella
# 15      Traffic Commute Time Index    5.00   Very Low  Andorra-La-Vella
# 16                 Pollution Index   64.08       High  Andorra-La-Vella
# 17        ƒ Quality of Life Index:       ?        NaN  Andorra-La-Vella
# 18          Purchasing Power Index   40.22   Very Low            Athens
# 19                    Safety Index    50.5   Moderate            Athens

# %%
def pivot_cities(df):

    df = df.pivot(index="city", columns="category", values=["numeral", "level"])
    
    colnames = ['climate', 'cost_of_living', 'health_care', 'pollution', 'property_income_ratio', 'purchasing_power',
                'safety', 'traffic_time', 'quality_of_life', 'climate_level', 'cost_of_living_level',
                'health_care_level', 'pollution_level', 'property_income_ratio_level', 'purchasing_power_level',
                'safety_level', 'traffic_time_level', 'quality_of_life_level']
    df.columns = colnames
    df = df.reset_index()
    
    return df

# %%
final_cities = pivot_cities(final_cities)

final_cities.head(20)
# Out:
#                 city climate cost_of_living health_care pollution  \
# 0          Amsterdam   87.45          84.26       69.45     30.79
# 1   Andorra-La-Vella       ?          66.75       69.44     64.08
# 2             Athens   95.18          59.56       56.17      57.3
# 3           Belgrade   84.14          40.53       53.72     63.57
# 4             Berlin   83.35          67.91       69.68     39.45
# 5         Bratislava   80.72          50.85       57.17     41.12
# 6           Brussels   83.85          74.91        74.5     62.36
# 7          Bucharest   75.61          41.06       54.34     75.53
# 8           Budapest   78.41          43.94        47.7     54.38
# 9           Chisinau   76.91          34.82       51.93     62.24
# 10        Copenhagen   83.74          93.09       78.15     21.47
# 11            Dublin   85.89          82.58        51.5     40.42
# 12          Helsinki   62.79          76.96       77.06     13.19
# 13              Kiev   69.95          33.13       55.55     66.08
# 14            Lisbon   98.59          52.13       71.49     34.91
# 15         Ljubljana   76.11          58.15       66.24     23.24
# 16            London   88.25          79.73       70.28     58.57
# 17        Luxembourg   82.62          86.39       73.71     21.59
# 18            Madrid   85.47          62.35       78.97     52.06
# 19             Minsk   64.37          35.31       62.59     41.56
#
#    property_income_ratio purchasing_power safety traffic_time quality_of_life  \
# 0                  10.98             80.9  67.32        29.88          168.08
# 1                   7.44            81.72  87.16         5.00               ?
# 2                  12.74            40.22   50.5        37.98          119.64
# 3                  22.22            34.52  62.02        35.89          107.76
# 4                   9.59            97.17  58.92        34.18          164.21
# 5                  13.37            61.26  68.68        30.89          147.31
# 6                   6.38            87.24  48.28        37.17          142.75
# 7                  10.54            50.77  72.64         42.3          117.42
# 8                  15.93            48.37  63.82        39.13          120.33
# 9                  13.26            25.83  54.82           28          111.91
# 10                  8.32            89.27  74.77        28.93          185.87
# 11                  9.65            67.08  50.42        40.58          136.12
# 12                  12.1            88.48  77.24        31.47          181.45
# 13                 11.97            38.42  52.94        43.11          106.49
# 14                 17.77            46.23  71.94        36.21          151.56
# 15                 13.51            58.09  78.72        27.72          165.79
# 16                 15.98            82.41  47.44        45.26          128.58
# 17                 11.41           102.04  71.91        33.24          182.73
# 18                    13            65.95  70.01        35.13          149.95
# 19                 15.88            33.05  75.55        30.34           135.2
#
#    climate_level cost_of_living_level health_care_level pollution_level  \
# 0      Very High             Moderate              High             Low
# 1            NaN             Moderate              High            High
# 2      Very High                  Low          Moderate        Moderate
# 3      Very High             Very Low          Moderate            High
# 4      Very High             Moderate              High             Low
# 5      Very High                  Low          Moderate        Moderate
# 6      Very High             Moderate              High            High
# 7           High             Very Low          Moderate            High
# 8           High             Very Low          Moderate        Moderate
# 9           High             Very Low          Moderate            High
# 10     Very High                 High              High             Low
# 11     Very High             Moderate          Moderate        Moderate
# 12          High             Moderate              High        Very Low
# 13          High             Very Low          Moderate            High
# 14     Very High                  Low              High             Low
# 15          High                  Low              High             Low
# 16     Very High             Moderate              High        Moderate
# 17     Very High             Moderate              High             Low
# 18     Very High                  Low              High        Moderate
# 19          High             Very Low              High        Moderate
#
#    property_income_ratio_level purchasing_power_level safety_level  \
# 0                     Moderate               Moderate         High
# 1                          Low               Moderate    Very High
# 2                         High               Very Low     Moderate
# 3                    Very High               Very Low         High
# 4                     Moderate                   High     Moderate
# 5                         High                    Low         High
# 6                          Low               Moderate     Moderate
# 7                     Moderate                    Low         High
# 8                         High                    Low         High
# 9                         High               Very Low     Moderate
# 10                    Moderate               Moderate         High
# 11                    Moderate               Moderate     Moderate
# 12                        High               Moderate         High
# 13                    Moderate               Very Low     Moderate
# 14                   Very High                    Low         High
# 15                        High                    Low         High
# 16                        High               Moderate     Moderate
# 17                    Moderate                   High         High
# 18                        High               Moderate         High
# 19                        High               Very Low         High
#
#    traffic_time_level quality_of_life_level
# 0                 Low             Very High
# 1            Very Low                   NaN
# 2            Moderate                  High
# 3            Moderate              Moderate
# 4                 Low             Very High
# 5                 Low                  High
# 6            Moderate                  High
# 7            Moderate                  High
# 8            Moderate                  High
# 9                 Low                  High
# 10                Low             Very High
# 11           Moderate                  High
# 12                Low             Very High
# 13           Moderate              Moderate
# 14           Moderate             Very High
# 15                Low             Very High
# 16               High                  High
# 17                Low             Very High
# 18           Moderate                  High
# 19                Low                  High

# %% [markdown]
# ## 3. Data cleaning on final table

# %% [markdown]
# ### 3.1
