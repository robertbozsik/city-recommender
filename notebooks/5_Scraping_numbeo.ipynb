# %% [markdown]
# # Obtaining socio-economic data
# #### Using pandas read_html to collect table data from https://www.numbeo.com/quality-of-life/in/Berlin

# %%
import pandas as pd
import lxml

# %% [markdown]
# ## 1. Getting city data
# ### 1.1 Define list of the European capital cities

# %%
city_list = ['Amsterdam', 'Andorra-La-Vella', 'Athens', 'Belgrade', 'Berlin', 'Bern', 
             'Bratislava', 'Brussels', 'Bucharest', 'Budapest', 'Chisinau', 'Copenhagen', 
             'Dublin', 'Helsinki', 'Kiev', 'Lisbon', 'Ljubljana', 'London', 'Luxembourg', 
             'Madrid', 'Minsk', 'Monaco', 'Moscow', 'Nicosia', 'Nuuk', 'Oslo', 'Paris', 
             'Podgorica', 'Prague', 'Reykjavik', 'Riga', 'Rome', 'San-Marino', 'Sarajevo', 
             'Skopje', 'Sofia', 'Stockholm', 'Tallinn', 'Tirana', 'Vaduz', 'Valletta', 'Vatican-City', 
             'Vienna', 'Vilnius', 'Warsaw', 'Zagreb']

# %% [markdown]
# ### 1.2 Creating a function to obtain data and put it into a dataframe for processing and modelling

# %%
test_list = ['Vienna', 'Berlin']

# %%
def get_city_info(city_list) -> list:
    
    # create empty database
    df = pd.DataFrame()
    errors = []
    
    # iterate over list of cities to obtain table data from Numbeo
    for city in city_list:
        try:
            table = pd.read_html(f'https://www.numbeo.com/quality-of-life/in/{city}')[3]
            table = (table.assign(city=city)
                      .rename(columns={0:'category', 1:'numeral', 2:'level'})
                      .drop([table.index[8]]))
            df = df.append(table)
        
        except:
            errors.append(city)
    
    df.reset_index(inplace=True, drop=True)
    
    # df = df.pivot(index='city', columns='category', values=['numeral', 'level'])
    
    # colnames = ['climate', 'cost_of_living', 'health_care', 'pollution', 'property_income_ratio', 'purchasing_power',
                #'safety', 'traffic_time', 'quality_of_life', 'climate_level', 'cost_of_living_level',
                #'health_care_level', 'pollution_level', 'property_income_ratio_level', 'purchasing_power_level',
                #'safety_level', 'traffic_time_level', 'quality_of_life_level']
                
    #df.columns = colnames
    #df = df.reset_index()
        
    return df, errors

# %%
get_city_info(test_list)
# Out:
# (                          category  numeral      level    city
#  0           Purchasing Power Index    87.18   Moderate  Vienna
#  1                     Safety Index    75.85       High  Vienna
#  2                Health Care Index    78.83       High  Vienna
#  3                    Climate Index    81.77  Very High  Vienna
#  4             Cost of Living Index    69.54   Moderate  Vienna
#  5   Property Price to Income Ratio    13.72       High  Vienna
#  6       Traffic Commute Time Index    26.78        Low  Vienna
#  7                  Pollution Index    18.15   Very Low  Vienna
#  8         ƒ Quality of Life Index:   185.43  Very High  Vienna
#  9           Purchasing Power Index   102.27       High  Berlin
#  10                    Safety Index    59.10   Moderate  Berlin
#  11               Health Care Index    69.94       High  Berlin
#  12                   Climate Index    83.35  Very High  Berlin
#  13            Cost of Living Index    69.03   Moderate  Berlin
#  14  Property Price to Income Ratio     9.38   Moderate  Berlin
#  15      Traffic Commute Time Index    33.84        Low  Berlin
#  16                 Pollution Index    39.04        Low  Berlin
#  17        ƒ Quality of Life Index:   166.99  Very High  Berlin,
#  [])

# %% [markdown]
# ## 2. Final data-set
# ### 2.1 Checking for cities not covered by Numbeo

# %%
#get_city_info(city_list)

# %% [markdown]
# **After running the function on the whole list San Marino, Vaduz and Vatican City appeared in the error list**

# %%
drop_cities = ['San-Marino', 'Vaduz', 'Vatican-City']

update_cities = [city for city in city_list if city not in drop_cities]

# %%
print(update_cities)
# Out:
# ['Amsterdam', 'Andorra-La-Vella', 'Athens', 'Belgrade', 'Berlin', 'Bern', 'Bratislava', 'Brussels', 'Bucharest', 'Budapest', 'Chisinau', 'Copenhagen', 'Dublin', 'Helsinki', 'Kiev', 'Lisbon', 'Ljubljana', 'London', 'Luxembourg', 'Madrid', 'Minsk', 'Monaco', 'Moscow', 'Nicosia', 'Nuuk', 'Oslo', 'Paris', 'Podgorica', 'Prague', 'Reykjavik', 'Riga', 'Rome', 'Sarajevo', 'Skopje', 'Sofia', 'Stockholm', 'Tallinn', 'Tirana', 'Valletta', 'Vienna', 'Vilnius', 'Warsaw', 'Zagreb']

# %% [markdown]
# ### 2.2 Now rerunning function with updated list

# %%
# get_city_info(update_cities)

# %% [markdown]
# ### 2.3 There seem to be no errors coming up, now to rewrite the function, so it returns a data-set again

# %%
def get_city(city_list) -> list:
    
    # create empty database
    df = pd.DataFrame()
    
    # iterate over list of cities to obtain table data from Numbeo    
    # removing index position 8, because it refers to a border
    for city in city_list:
        table = pd.read_html(f'https://www.numbeo.com/quality-of-life/in/{city}')[3]
        table = (table.assign(city=city)
                      .rename(columns={0:'category', 1:'numeral', 2:'level'}))
        df = df.append(table)
    
    df.reset_index(inplace=True, drop=True)
  
    return df

# %%
#all_cities = 
get_city(test_list)
# Out:
#                           category  numeral      level    city
# 0           Purchasing Power Index    87.18   Moderate  Vienna
# 1                     Safety Index    75.85       High  Vienna
# 2                Health Care Index    78.83       High  Vienna
# 3                    Climate Index    81.77  Very High  Vienna
# 4             Cost of Living Index    69.54   Moderate  Vienna
# 5   Property Price to Income Ratio    13.72       High  Vienna
# 6       Traffic Commute Time Index    26.78        Low  Vienna
# 7                  Pollution Index    18.15   Very Low  Vienna
# 8                              NaN      NaN        NaN  Vienna
# 9         ƒ Quality of Life Index:   185.43  Very High  Vienna
# 10          Purchasing Power Index   102.27       High  Berlin
# 11                    Safety Index    59.10   Moderate  Berlin
# 12               Health Care Index    69.94       High  Berlin
# 13                   Climate Index    83.35  Very High  Berlin
# 14            Cost of Living Index    69.03   Moderate  Berlin
# 15  Property Price to Income Ratio     9.38   Moderate  Berlin
# 16      Traffic Commute Time Index    33.84        Low  Berlin
# 17                 Pollution Index    39.04        Low  Berlin
# 18                             NaN      NaN        NaN  Berlin
# 19        ƒ Quality of Life Index:   166.99  Very High  Berlin

# %%
# all_cities

# %% [markdown]
# ### 2.4 Checking values of Index and Unnamed: 1 columns
# There seems to be a city whose data was pushed back by one.

# %%
# all_cities['Index'].value_counts()

# %%
# all_cities['Unnamed: 1'].value_counts()

# %%
# all_cities.loc[all_cities['Unnamed: 1'] == 209.07]

# %% [markdown]
# The data for the city of Bern seems to have been scraped incorrectly. Let's check what data Numbeo actually has available.

# %%
pd.read_html(f'https://www.numbeo.com/quality-of-life/in/Bern')[3]
# Out:
#                     Index  Unnamed: 1
# 0  Quality of Life Index:      211.54

# %% [markdown]
# Perhaps we are reading the wrong table from Numbeo, let's try the others.

# %%
pd.read_html(f'https://www.numbeo.com/quality-of-life/in/Bern')[4]
# Out:
#                                 0       1          2
# 0          Purchasing Power Index  130.37  Very High
# 1                    Safety Index   80.61  Very High
# 2               Health Care Index   74.76       High
# 3                   Climate Index   75.97       High
# 4            Cost of Living Index  117.95  Very High
# 5  Property Price to Income Ratio    7.05        Low
# 6      Traffic Commute Time Index   19.77   Very Low
# 7                 Pollution Index   11.11   Very Low
# 8                             NaN     NaN        NaN
# 9        ƒ Quality of Life Index:  211.54  Very High

# %% [markdown]
# It seems as though there is not enough user information for Bern and there is a notice table in the html
# pushing it to index position 4. We will delete Bern from the list and add it later manually to the list.

# %%
update_cities.remove('Bern')

# %%
print(update_cities)
# Out:
# ['Amsterdam', 'Andorra-La-Vella', 'Athens', 'Belgrade', 'Berlin', 'Bratislava', 'Brussels', 'Bucharest', 'Budapest', 'Chisinau', 'Copenhagen', 'Dublin', 'Helsinki', 'Kiev', 'Lisbon', 'Ljubljana', 'London', 'Luxembourg', 'Madrid', 'Minsk', 'Monaco', 'Moscow', 'Nicosia', 'Nuuk', 'Oslo', 'Paris', 'Podgorica', 'Prague', 'Reykjavik', 'Riga', 'Rome', 'Sarajevo', 'Skopje', 'Sofia', 'Stockholm', 'Tallinn', 'Tirana', 'Valletta', 'Vienna', 'Vilnius', 'Warsaw', 'Zagreb']

# %%
#final_cities = get_city(update_cities)

# %%
def get_city(city_list) -> list:
    
    # create empty database
    df = pd.DataFrame()
    
    # iterate over list of cities to obtain table data from Numbeo    
    # removing index position 8, because it refers to a border
    for city in city_list:
        table = pd.read_html(f'https://www.numbeo.com/quality-of-life/in/{city}')[3]
        table = (table.assign(city=city)
                      .rename(columns={0:'category', 1:'numeral', 2:'level'})
                      .drop([table.index[8]]))
        df = df.append(table)
    
    df.reset_index(inplace=True, drop=True)
  
    return df

# %%
final_cities = get_city(update_cities)

# %%
final_cities.head(20)
# Out:
#                           category numeral      level              city
# 0           Purchasing Power Index   83.85   Moderate         Amsterdam
# 1                     Safety Index   67.13       High         Amsterdam
# 2                Health Care Index   69.45       High         Amsterdam
# 3                    Climate Index   87.45  Very High         Amsterdam
# 4             Cost of Living Index   85.61   Moderate         Amsterdam
# 5   Property Price to Income Ratio   11.03   Moderate         Amsterdam
# 6       Traffic Commute Time Index   29.88        Low         Amsterdam
# 7                  Pollution Index   30.79        Low         Amsterdam
# 8         ƒ Quality of Life Index:  168.98  Very High         Amsterdam
# 9           Purchasing Power Index   86.69   Moderate  Andorra-La-Vella
# 10                    Safety Index   87.54  Very High  Andorra-La-Vella
# 11               Health Care Index   69.44       High  Andorra-La-Vella
# 12                   Climate Index       ?        NaN  Andorra-La-Vella
# 13            Cost of Living Index   66.57   Moderate  Andorra-La-Vella
# 14  Property Price to Income Ratio    7.44        Low  Andorra-La-Vella
# 15      Traffic Commute Time Index    5.00   Very Low  Andorra-La-Vella
# 16                 Pollution Index   64.08       High  Andorra-La-Vella
# 17        ƒ Quality of Life Index:       ?        NaN  Andorra-La-Vella
# 18          Purchasing Power Index   41.45   Very Low            Athens
# 19                    Safety Index    50.3   Moderate            Athens

# %% [markdown]
# **Add Bern manually**

# %%
bern = pd.read_html(f'https://www.numbeo.com/quality-of-life/in/Bern')[4]
bern = (bern.assign(city='Bern')
        .rename(columns={0:'category', 1:'numeral', 2:'level'})
        .drop([bern.index[8]]))

bern
# Out:
#                          category  numeral      level  city
# 0          Purchasing Power Index   130.37  Very High  Bern
# 1                    Safety Index    80.61  Very High  Bern
# 2               Health Care Index    74.76       High  Bern
# 3                   Climate Index    75.97       High  Bern
# 4            Cost of Living Index   117.95  Very High  Bern
# 5  Property Price to Income Ratio     7.05        Low  Bern
# 6      Traffic Commute Time Index    19.77   Very Low  Bern
# 7                 Pollution Index    11.11   Very Low  Bern
# 9        ƒ Quality of Life Index:   211.54  Very High  Bern

# %%
final_cities = final_cities.append(bern)
final_cities.reset_index(inplace=True, drop=True)

final_cities[final_cities['city'] == 'Bern']
# Out:
#                            category numeral      level  city
# 378          Purchasing Power Index  130.37  Very High  Bern
# 379                    Safety Index   80.61  Very High  Bern
# 380               Health Care Index   74.76       High  Bern
# 381                   Climate Index   75.97       High  Bern
# 382            Cost of Living Index  117.95  Very High  Bern
# 383  Property Price to Income Ratio    7.05        Low  Bern
# 384      Traffic Commute Time Index   19.77   Very Low  Bern
# 385                 Pollution Index   11.11   Very Low  Bern
# 386        ƒ Quality of Life Index:  211.54  Very High  Bern

# %% [markdown]
# ### 2.5 Now to pivot the table so each city only has one row

# %%
def pivot_cities(df):

    df = df.pivot(index='city', columns='category', values=['numeral', 'level'])
    
    colnames = ['climate', 'cost_of_living', 'health_care', 'pollution', 'property_income_ratio', 'purchasing_power',
                'safety', 'traffic_time', 'quality_of_life', 'climate_level', 'cost_of_living_level',
                'health_care_level', 'pollution_level', 'property_income_ratio_level', 'purchasing_power_level',
                'safety_level', 'traffic_time_level', 'quality_of_life_level']
    
    df.columns = colnames
    df = df.reset_index()
    
    return df

# %%
final_cities = pivot_cities(final_cities)

final_cities.head(20)
# Out:
#                 city climate cost_of_living health_care pollution  \
# 0          Amsterdam   87.45          85.61       69.45     30.79
# 1   Andorra-La-Vella       ?          66.57       69.44     64.08
# 2             Athens   95.18          60.86       56.17      57.3
# 3           Belgrade   84.14          41.47       53.69     63.57
# 4             Berlin   83.35          69.03       69.94     39.04
# 5               Bern   75.97         117.95       74.76     11.11
# 6         Bratislava   80.72          52.19       57.17     41.12
# 7           Brussels   83.85          75.41        74.5     62.36
# 8          Bucharest   75.61          42.68       54.19     75.64
# 9           Budapest   78.41          46.17       47.86     54.13
# 10          Chisinau   76.91          34.65       51.93     62.24
# 11        Copenhagen   83.74          95.13       78.15     21.47
# 12            Dublin   85.89          84.82       51.58     40.28
# 13          Helsinki   62.79          78.45       77.21     13.09
# 14              Kiev   69.95          32.84       55.81     65.86
# 15            Lisbon   98.59          53.25        71.5     34.73
# 16         Ljubljana   76.11          59.44       66.24     23.24
# 17            London   88.25          82.04       70.51     57.98
# 18        Luxembourg   82.62          88.45       73.71     21.59
# 19            Madrid   85.47          63.68       79.06     51.89
#
#    property_income_ratio purchasing_power safety traffic_time quality_of_life  \
# 0                  11.03            83.85  67.13        29.88          168.98
# 1                   7.44            86.69  87.54         5.00               ?
# 2                  12.85            41.45   50.3        37.98          119.79
# 3                  22.22            35.72  62.08        35.79           108.2
# 4                   9.38           102.27   59.1        33.84          166.99
# 5                   7.05           130.37  80.61        19.77          211.54
# 6                  13.18            64.14  68.76        30.89          148.56
# 7                    6.4            91.77  48.41        37.17          144.56
# 8                  10.54            51.93  72.47         42.3          117.51
# 9                  15.96            49.74  63.87        39.13          120.88
# 10                 13.23            27.32  54.76           28          112.53
# 11                  8.38            91.66  74.85         28.9          186.61
# 12                  9.67            69.02   50.5        40.58          136.82
# 13                    12            92.37  77.31        31.47          183.11
# 14                 11.93            40.06  53.03        43.11           107.5
# 15                 17.39            48.15  71.99        36.21          152.75
# 16                 13.51            60.12  78.77        27.72          166.49
# 17                 15.31            85.86   46.8        44.94          130.73
# 18                 11.63           103.77  71.91        33.24             183
# 19                 12.83            68.56  70.09        34.96          151.31
#
#    climate_level cost_of_living_level health_care_level pollution_level  \
# 0      Very High             Moderate              High             Low
# 1            NaN             Moderate              High            High
# 2      Very High                  Low          Moderate        Moderate
# 3      Very High             Very Low          Moderate            High
# 4      Very High             Moderate              High             Low
# 5           High            Very High              High        Very Low
# 6      Very High                  Low          Moderate        Moderate
# 7      Very High             Moderate              High            High
# 8           High             Very Low          Moderate            High
# 9           High                  Low          Moderate        Moderate
# 10          High             Very Low          Moderate            High
# 11     Very High                 High              High             Low
# 12     Very High             Moderate          Moderate        Moderate
# 13          High             Moderate              High        Very Low
# 14          High             Very Low          Moderate            High
# 15     Very High                  Low              High             Low
# 16          High                  Low              High             Low
# 17     Very High             Moderate              High        Moderate
# 18     Very High             Moderate              High             Low
# 19     Very High                  Low              High        Moderate
#
#    property_income_ratio_level purchasing_power_level safety_level  \
# 0                     Moderate               Moderate         High
# 1                          Low               Moderate    Very High
# 2                         High               Very Low     Moderate
# 3                    Very High               Very Low         High
# 4                     Moderate                   High     Moderate
# 5                          Low              Very High    Very High
# 6                         High                    Low         High
# 7                          Low               Moderate     Moderate
# 8                     Moderate                    Low         High
# 9                         High                    Low         High
# 10                        High               Very Low     Moderate
# 11                    Moderate               Moderate         High
# 12                    Moderate               Moderate     Moderate
# 13                        High               Moderate         High
# 14                    Moderate               Very Low     Moderate
# 15                   Very High                    Low         High
# 16                        High                    Low         High
# 17                        High               Moderate     Moderate
# 18                    Moderate                   High         High
# 19                        High               Moderate         High
#
#    traffic_time_level quality_of_life_level
# 0                 Low             Very High
# 1            Very Low                   NaN
# 2            Moderate                  High
# 3            Moderate              Moderate
# 4                 Low             Very High
# 5            Very Low             Very High
# 6                 Low                  High
# 7            Moderate                  High
# 8            Moderate                  High
# 9            Moderate                  High
# 10                Low                  High
# 11                Low             Very High
# 12           Moderate                  High
# 13                Low             Very High
# 14           Moderate              Moderate
# 15           Moderate             Very High
# 16                Low             Very High
# 17           Moderate                  High
# 18                Low             Very High
# 19                Low             Very High

# %% [markdown]
# ## 3. Data cleaning on final table

# %% [markdown]
# ### 3.1 replacing the one '?' with NaN

# %%
import numpy as np

# %%
final_cities = final_cities.replace('?', np.nan)
final_cities
# Out:
#                 city climate cost_of_living health_care pollution  \
# 0          Amsterdam   87.45          85.61       69.45     30.79
# 1   Andorra-La-Vella     NaN          66.57       69.44     64.08
# 2             Athens   95.18          60.86       56.17      57.3
# 3           Belgrade   84.14          41.47       53.69     63.57
# 4             Berlin   83.35          69.03       69.94     39.04
# 5               Bern   75.97         117.95       74.76     11.11
# 6         Bratislava   80.72          52.19       57.17     41.12
# 7           Brussels   83.85          75.41        74.5     62.36
# 8          Bucharest   75.61          42.68       54.19     75.64
# 9           Budapest   78.41          46.17       47.86     54.13
# 10          Chisinau   76.91          34.65       51.93     62.24
# 11        Copenhagen   83.74          95.13       78.15     21.47
# 12            Dublin   85.89          84.82       51.58     40.28
# 13          Helsinki   62.79          78.45       77.21     13.09
# 14              Kiev   69.95          32.84       55.81     65.86
# 15            Lisbon   98.59          53.25        71.5     34.73
# 16         Ljubljana   76.11          59.44       66.24     23.24
# 17            London   88.25          82.04       70.51     57.98
# 18        Luxembourg   82.62          88.45       73.71     21.59
# 19            Madrid   85.47          63.68       79.06     51.89
# 20             Minsk   64.37          35.58       62.59     41.56
# 21            Monaco   94.90            NaN       71.53     80.23
# 22            Moscow   55.83          41.54       62.91     57.35
# 23           Nicosia   86.01          66.56       50.91     61.04
# 24              Nuuk   24.01         110.04          75     70.94
# 25              Oslo   59.99          99.72       75.33     25.34
# 26             Paris   88.39          92.16       78.68     63.41
# 27         Podgorica    88.4          42.65       40.31      48.6
# 28            Prague   80.67          51.69        74.6     34.42
# 29         Reykjavik   68.81          94.65       66.88     15.33
# 30              Riga    74.7          53.04       60.73     38.65
# 31              Rome    93.7          75.62       59.35      66.4
# 32          Sarajevo   78.18          38.88       60.13     69.24
# 33            Skopje    76.3          37.58       55.93      82.9
# 34             Sofia   76.01           43.8       57.24     69.24
# 35         Stockholm   69.67          83.57        66.9     20.05
# 36           Tallinn   64.28          57.19       71.14     22.13
# 37            Tirana   86.43          40.71       48.95     87.45
# 38          Valletta   97.44          77.69       58.86     74.23
# 39            Vienna   81.77          69.54       78.83     18.15
# 40           Vilnius   66.59          48.01       71.32     23.34
# 41            Warsaw   74.61          46.13       53.37     66.79
# 42            Zagreb   82.19          54.41       65.33     31.37
#
#    property_income_ratio purchasing_power safety traffic_time  \
# 0                  11.03            83.85  67.13        29.88
# 1                   7.44            86.69  87.54         5.00
# 2                  12.85            41.45   50.3        37.98
# 3                  22.22            35.72  62.08        35.79
# 4                   9.38           102.27   59.1        33.84
# 5                   7.05           130.37  80.61        19.77
# 6                  13.18            64.14  68.76        30.89
# 7                    6.4            91.77  48.41        37.17
# 8                  10.54            51.93  72.47         42.3
# 9                  15.96            49.74  63.87        39.13
# 10                 13.23            27.32  54.76           28
# 11                  8.38            91.66  74.85         28.9
# 12                  9.67            69.02   50.5        40.58
# 13                    12            92.37  77.31        31.47
# 14                 11.93            40.06  53.03        43.11
# 15                 17.39            48.15  71.99        36.21
# 16                 13.51            60.12  78.77        27.72
# 17                 15.31            85.86   46.8        44.94
# 18                 11.63           103.77  71.91        33.24
# 19                 12.83            68.56  70.09        34.96
# 20                 15.82            33.38  75.63        30.34
# 21                 48.88              NaN  79.26        18.33
# 22                 19.26            51.46   60.7        51.65
# 23                  6.21            58.69  68.46        26.15
# 24                  8.29             72.3  72.02        18.75
# 25                 10.91            86.86  63.52        31.92
# 26                 21.16            72.77  48.47        41.82
# 27                 12.86            37.29  49.59        13.11
# 28                 18.03            62.26  75.97        32.38
# 29                   6.5            76.74  77.74        20.17
# 30                  9.47            50.97  61.59         31.9
# 31                 16.75            55.17  48.37        42.43
# 32                  9.64            54.06  53.02        28.84
# 33                 13.48             34.7  56.12         28.6
# 34                  9.61            49.49  57.82        30.88
# 35                 14.68            82.38  55.32        36.53
# 36                  9.29            66.18  77.11        26.58
# 37                 17.15            28.46  61.25        40.46
# 38                 16.71            39.47  68.57           34
# 39                 13.72            87.18  75.85        26.78
# 40                  11.6            60.82  72.22        27.61
# 41                 15.61            53.55  70.58        36.16
# 42                  13.7            51.74  78.04        31.52
#
#     quality_of_life climate_level cost_of_living_level health_care_level  \
# 0            168.98     Very High             Moderate              High
# 1               NaN           NaN             Moderate              High
# 2            119.79     Very High                  Low          Moderate
# 3            108.20     Very High             Very Low          Moderate
# 4            166.99     Very High             Moderate              High
# 5            211.54          High            Very High              High
# 6            148.56     Very High                  Low          Moderate
# 7            144.56     Very High             Moderate              High
# 8            117.51          High             Very Low          Moderate
# 9            120.88          High                  Low          Moderate
# 10           112.53          High             Very Low          Moderate
# 11           186.61     Very High                 High              High
# 12           136.82     Very High             Moderate          Moderate
# 13           183.11          High             Moderate              High
# 14           107.50          High             Very Low          Moderate
# 15           152.75     Very High                  Low              High
# 16           166.49          High                  Low              High
# 17           130.73     Very High             Moderate              High
# 18           183.00     Very High             Moderate              High
# 19           151.31     Very High                  Low              High
# 20           135.41          High             Very Low              High
# 21              NaN     Very High                  NaN              High
# 22           107.23      Moderate             Very Low              High
# 23           140.10     Very High             Moderate          Moderate
# 24           126.98      Moderate            Very High              High
# 25           162.89      Moderate                 High              High
# 26           120.72     Very High                 High              High
# 27           129.22     Very High             Very Low          Moderate
# 28           157.28     Very High                  Low              High
# 29           182.99          High                 High              High
# 30           143.88          High                  Low              High
# 31           111.43     Very High             Moderate          Moderate
# 32           124.15          High             Very Low              High
# 33           102.95          High             Very Low          Moderate
# 34           121.35          High             Very Low          Moderate
# 35           155.93          High             Moderate              High
# 36           171.86          High                  Low              High
# 37            90.65     Very High             Very Low          Moderate
# 38           115.13     Very High             Moderate          Moderate
# 39           185.43     Very High             Moderate              High
# 40           165.39          High                  Low              High
# 41           120.11          High                  Low          Moderate
# 42           157.43     Very High                  Low              High
#
#    pollution_level property_income_ratio_level purchasing_power_level  \
# 0              Low                    Moderate               Moderate
# 1             High                         Low               Moderate
# 2         Moderate                        High               Very Low
# 3             High                   Very High               Very Low
# 4              Low                    Moderate                   High
# 5         Very Low                         Low              Very High
# 6         Moderate                        High                    Low
# 7             High                         Low               Moderate
# 8             High                    Moderate                    Low
# 9         Moderate                        High                    Low
# 10            High                        High               Very Low
# 11             Low                    Moderate               Moderate
# 12        Moderate                    Moderate               Moderate
# 13        Very Low                        High               Moderate
# 14            High                    Moderate               Very Low
# 15             Low                   Very High                    Low
# 16             Low                        High                    Low
# 17        Moderate                        High               Moderate
# 18             Low                    Moderate                   High
# 19        Moderate                        High               Moderate
# 20        Moderate                        High               Very Low
# 21       Very High                   Very High                    NaN
# 22        Moderate                   Very High                    Low
# 23            High                         Low                    Low
# 24            High                    Moderate               Moderate
# 25             Low                    Moderate               Moderate
# 26            High                   Very High               Moderate
# 27        Moderate                        High               Very Low
# 28             Low                   Very High                    Low
# 29        Very Low                         Low               Moderate
# 30             Low                    Moderate                    Low
# 31            High                   Very High                    Low
# 32            High                    Moderate                    Low
# 33       Very High                        High               Very Low
# 34            High                    Moderate                    Low
# 35             Low                        High               Moderate
# 36             Low                    Moderate               Moderate
# 37       Very High                   Very High               Very Low
# 38            High                   Very High               Very Low
# 39        Very Low                        High               Moderate
# 40             Low                    Moderate                    Low
# 41            High                        High                    Low
# 42             Low                        High                    Low
#
#    safety_level traffic_time_level quality_of_life_level
# 0          High                Low             Very High
# 1     Very High           Very Low                   NaN
# 2      Moderate           Moderate                  High
# 3          High           Moderate              Moderate
# 4      Moderate                Low             Very High
# 5     Very High           Very Low             Very High
# 6          High                Low                  High
# 7      Moderate           Moderate                  High
# 8          High           Moderate                  High
# 9          High           Moderate                  High
# 10     Moderate                Low                  High
# 11         High                Low             Very High
# 12     Moderate           Moderate                  High
# 13         High                Low             Very High
# 14     Moderate           Moderate              Moderate
# 15         High           Moderate             Very High
# 16         High                Low             Very High
# 17     Moderate           Moderate                  High
# 18         High                Low             Very High
# 19         High                Low             Very High
# 20         High                Low                  High
# 21         High           Very Low                   NaN
# 22         High               High              Moderate
# 23         High                Low                  High
# 24         High           Very Low                  High
# 25         High                Low             Very High
# 26     Moderate           Moderate                  High
# 27     Moderate           Very Low                  High
# 28         High                Low             Very High
# 29         High           Very Low             Very High
# 30         High                Low                  High
# 31     Moderate           Moderate                  High
# 32     Moderate                Low                  High
# 33     Moderate                Low              Moderate
# 34     Moderate                Low                  High
# 35     Moderate           Moderate             Very High
# 36         High                Low             Very High
# 37         High           Moderate              Moderate
# 38         High                Low                  High
# 39         High                Low             Very High
# 40         High                Low             Very High
# 41         High           Moderate                  High
# 42         High                Low             Very High

# %% [markdown]
# ### 3.2 Fixing the data types

# %%
final_cities.dtypes
# Out:
# city                            object
# climate                         object
# cost_of_living                  object
# health_care                     object
# pollution                       object
# property_income_ratio           object
# purchasing_power                object
# safety                          object
# traffic_time                    object
# quality_of_life                float64
# climate_level                   object
# cost_of_living_level            object
# health_care_level               object
# pollution_level                 object
# property_income_ratio_level     object
# purchasing_power_level          object
# safety_level                    object
# traffic_time_level              object
# quality_of_life_level           object
# dtype: object

# %%
cols_to_float = ['climate', 'cost_of_living', 'health_care', 'pollution',
                 'property_income_ratio', 'purchasing_power', 'safety',
                 'traffic_time']

# %%
final_cities[cols_to_float] = final_cities[cols_to_float].apply(pd.to_numeric)

# %%
final_cities.dtypes
# Out:
# city                            object
# climate                        float64
# cost_of_living                 float64
# health_care                    float64
# pollution                      float64
# property_income_ratio          float64
# purchasing_power               float64
# safety                         float64
# traffic_time                   float64
# quality_of_life                float64
# climate_level                   object
# cost_of_living_level            object
# health_care_level               object
# pollution_level                 object
# property_income_ratio_level     object
# purchasing_power_level          object
# safety_level                    object
# traffic_time_level              object
# quality_of_life_level           object
# dtype: object

# %% [markdown]
# ## 4. Exporting to json format

# %%
final_cities.to_json('../data/Socio_economic_data.json')
