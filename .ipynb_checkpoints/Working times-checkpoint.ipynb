# %% [markdown]
# # Checking data for working times
# #### https://www.ubs.com/microsites/prices-earnings/en/open-data/

# %%
import pandas as pd

# %%
pd.read_excel("data/UBS_working_time_OpenData.xlsx")
# Out:
#         Year       City                        Main Section  \
# 0       1971  Amsterdam       Earnings: Automobile Mechanic
# 1       1971  Amsterdam       Earnings: Automobile Mechanic
# 2       1971  Amsterdam       Earnings: Automobile Mechanic
# 3       1971  Amsterdam       Earnings: Automobile Mechanic
# 4       1971  Amsterdam       Earnings: Automobile Mechanic
# ...      ...        ...                                 ...
# 110849  2006  Stockholm  Prices: Women's and Men's Clothing
# 110850  2006     Sydney  Prices: Women's and Men's Clothing
# 110851  2006      Tokyo  Prices: Women's and Men's Clothing
# 110852  2006     Vienna  Prices: Women's and Men's Clothing
# 110853  2006     Zurich  Prices: Women's and Men's Clothing
#
#                               Sub-Section    Value
# 0                             Gross (USD)     3934
# 1                    Gross (Zurich = 100)       89
# 2            Gross after Tax (% of gross)       87
# ...
