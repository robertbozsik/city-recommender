# %% [markdown]
# # Checking data for purchasing power
#
# ### site: https://www.ubs.com/microsites/prices-earnings/en/open-data/

# %%
import pandas as pd

# %%
purchasing_power = pd.read_excel("data/UBS_PricesAndEarnings_OpenData.xlsx")

# %%
purchasing_power.head(20)
# Out:
#     Year       City                   Main Section  \
# 0   1971  Amsterdam  Earnings: Automobile Mechanic
# 1   1971  Amsterdam  Earnings: Automobile Mechanic
# 2   1971  Amsterdam  Earnings: Automobile Mechanic
# 3   1971  Amsterdam  Earnings: Automobile Mechanic
# 4   1971  Amsterdam  Earnings: Automobile Mechanic
# 5   1971  Amsterdam  Earnings: Automobile Mechanic
# 6   1971  Amsterdam  Earnings: Automobile Mechanic
# 7   1971  Amsterdam  Earnings: Automobile Mechanic
# 8   1971  Amsterdam    Earnings: Bank Credit Clerk
# 9   1971  Amsterdam    Earnings: Bank Credit Clerk
# 10  1971  Amsterdam    Earnings: Bank Credit Clerk
# 11  1971  Amsterdam    Earnings: Bank Credit Clerk
# 12  1971  Amsterdam    Earnings: Bank Credit Clerk
# 13  1971  Amsterdam    Earnings: Bank Credit Clerk
# 14  1971  Amsterdam    Earnings: Bank Credit Clerk
# 15  1971  Amsterdam    Earnings: Bank Credit Clerk
# 16  1971  Amsterdam    Earnings: Bank Credit Clerk
# ...

# %%
purchasing_power["Main Section"].value_counts()
# Out:
# Earnings: Bus Driver                                                          6748
# Prices: Housing                                                               5913
# Earnings: Secretary                                                           5711
# Earnings: Automobile Mechanic                                                 5413
# Earnings: Primary School Teacher                                              5339
# Prices: Women's and Men's Clothing                                            5253
# Earnings: Department Manager                                                  5075
# Earnings: Sales Assistant                                                     4520
# Earnings: Cook                                                                4509
# Earnings: Bank Credit Clerk                                                   4468
# Earnings: Industrial Technician                                               4093
# ...

# %%
purchasing_power.loc[(purchasing_power["City"] == "Vienna") & (purchasing_power["Year"] > 2017)]
# Out:
#         Year    City                        Main Section  \
# 94741   2018  Vienna  General: Domestic Purchasing Power
# 95295   2018  Vienna                General: Price Level
# 95755   2018  Vienna                General: Price Level
# 99929   2018  Vienna       Earnings: Automobile Mechanic
# 99930   2018  Vienna      Earnings: Automobile Mechanic
# ...      ...     ...                                 ...
# 107421  2018  Vienna        Earnings: Practice Assistant
# 108303  2018  Vienna    Earnings: Primary School Teacher
# 108727  2018  Vienna           Earnings: Product Manager
# 109512  2018  Vienna           Earnings: Sales Assistant
# 110393  2018  Vienna                 Earnings: Secretary
#
#                            Sub-Section    Value
# 94741             Net (New York = 100)  90.9259
# 95295      excl. rent (New York = 100)  83.0122
# 95755      incl. rent (New York = 100)  72.7845
# 99929                      Gross (USD)  35752.9
# ...
